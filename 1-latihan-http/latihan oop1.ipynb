# %%
import requests
r = requests.get('http://itb.ac.id')
print(r.status_code)
print(r.headers)
print(r.content)
# Out:
# 200
# {'Server': 'nginx/1.6.2', 'Date': 'Mon, 09 Sep 2019 02:51:55 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': 'itb_sessions=d4a3951421b1831437c11e46621a6ef7659c6669; path=/; domain=www.itb.ac.id; HttpOnly', 'Expires': 'Thu, 19 Nov 1981 08:52:00 GMT', 'Cache-Control': 'no-store, no-cache, must-revalidate, post-check=0, pre-check=0', 'Pragma': 'no-cache', 'Content-Encoding': 'gzip', 'Vary': 'Accept-Encoding', 'X-Frame-Options': 'DENY'}
# b'<!DOCTYPE html>\n<!--<html data-ng-app="app" class="ie8 no-js ie" id="ng-app" xmlns:ng="http://angularjs.org">-->\n<html data-ng-app="app" class="ie8 no-js ie" id="ng-app" >\n<head>\n        <meta charset="utf-8">\n       <!-- <meta http-equiv="Content-Type" content="text/html; charset=utf-8">-->\n\n        <meta name="viewport" content="width=device-width, initial-scale=1">\n\n        <!--<meta name="keywords" content="">\n        <meta name="description" content="">-->\n\n        <meta name="title" content="Institut Teknologi Bandung, Bandung, Indonesia,  Beranda - ">\n        <meta name="keywords" content="itb, institut teknologi bandung, bandung, indonesia, ITB, Institution of higher learning of science, technology, and fine arts, with a mission of education, research, and services to the community.">\n        <meta name="author" content="Webmaster Team, Direktorat  Sistem dan Teknologi Informasi  ITB">\n        <meta name="description" content="In Harmoniae Progressio - Kemajuan dalam keselarasan">\n        <!-- Schema.org markup for Google+\n        <meta itemprop="name" content="Institut Teknologi Bandung">\n        <meta itemprop="description" content="This is the page description">\n        <meta itemprop="image" content="https://www.itb.ac.id/images/logo-itb.png">\n        -->\n        <!--S:fb meta-->\n        <meta property="og:type" content="article" />\n        <meta property="og:image" content=https://itb.ac.id/themes/default/images/logoitb.png />\n        <meta property="og:title" content="Beranda - " />\n        <meta property="og:url" content="https://www.itb.ac.id/" />\n        <meta property="og:site_name" content="Institut Teknologi Bandung" />\n        <meta property="og:description" content="In Harmoniae Progressio - Kemajuan dalam keselarasan" />\n        <meta property="fb:admins" content="10208322639923490" />\n        <meta property="fb:app_id" content="829371137173499" />\n        <!-- e:fb meta -->\n\n        <!-- S:tweeter card -->\n        <meta name="twitter:card" content="summary_large_image" />\n        <meta name="twitter:site" content="@itbofficial" />\n        <meta name="twitter:creator" content="@itbofficial">\n        <meta name="twitter:title" content="Beranda - " />\n        <meta name="twitter:description" content="In Harmoniae Progressio - Kemajuan dalam keselarasan" />\n        <meta name="twitter:image" content=https://itb.ac.id/themes/default/images/logoitb.png />\n    <!-- E:tweeter card -->\n\n    <title>Beranda - Institut Teknologi Bandung</title>\n    <link href="https://www.itb.ac.id/" rel="canonical" />\n    <!--<link href="https://fonts.googleapis.com/css?family=Roboto:300,400,700" rel="stylesheet">-->\n    <!--<link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?v=">-->\n    <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico">\n    <link rel="icon" type="image/x-icon" href="/favicon.ico">\n\n                                            <link rel="stylesheet"\n                      href="https://www.itb.ac.id/assets/css/bootstrap.min.css">\n                                                <link rel="stylesheet"\n                      href="https://www.itb.ac.id/assets/css/angular-bootstrap-calendar.min.css">\n                                                <link rel="stylesheet"\n                      href="https://www.itb.ac.id/themes/default/css/main.css">\n                                                <link rel="stylesheet"\n                      href="https://www.itb.ac.id/themes/default/css/style.css">\n                                                <link rel="stylesheet"\n                      href="https://www.itb.ac.id/themes/default/css/carousel.css">\n                                                <link rel="stylesheet"\n                      href="https://www.itb.ac.id/themes/default/css/font-awesome.min.css">\n                                                <link rel="stylesheet"\n                      href="https://www.itb.ac.id/th ...

# %%
import requests
r = requests.get('http://localhost:8080')
print(r.status_code)
print(r.headers)
print(r.content)
# Out:
# 200
# {'Server': 'SimpleHTTP/0.6 Python/3.7.4', 'Date': 'Mon, 09 Sep 2019 02:53:02 GMT', 'Content-type': 'text/html', 'Content-Length': '134', 'Last-Modified': 'Mon, 09 Sep 2019 02:46:35 GMT'}
# b'<html>\n    <head>\n        <title>My Homepage</title>\n    </head>\n    <body>\n        My First HTTP Server in Python\n    </body>\n</html>'

# %%
import http.server
import socketserver

PORT = 8080
Handler = http.server.SimpleHTTPRequestHandler

with socketserver.TCPServer(("", PORT), Handler) as httpd:
    print("serving at port", PORT)
    httpd.serve_forever()
# Out:
# serving at port 8080
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-a42e31f48a6d> in <module>
#       7 with socketserver.TCPServer(("", PORT), Handler) as httpd:
#       8     print("serving at port", PORT)
# ----> 9     httpd.serve_forever()
#
# C:\ProgramData\Anaconda3\lib\socketserver.py in serve_forever(self, poll_interval)
#     230
#     231                 while not self.__shutdown_request:
# --> 232                     ready = selector.select(poll_interval)
#     233                     # bpo-35017: shutdown() called during select(), exit immediately.
#     234                     if self.__shutdown_request:
#
# C:\ProgramData\Anaconda3\lib\selectors.py in select(self, timeout)
#     321         ready = []
#     322         try:
# --> 323             r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     324         except InterruptedError:
#     325             return ready
#
# C:\ProgramData\Anaconda3\lib\selectors.py in _select(self, r, w, _, timeout)
#     312     if sys.platform == 'win32':
#     313         def _select(self, r, w, _, timeout=None):
# --> 314             r, w, x = select.select(r, w, w, timeout)
#     315             return r, w + x, []
#     316     else:
#
# KeyboardInterrupt:

# %%
import http.server
import socketserver

PORT = 8081
Handler = http.server.SimpleHTTPRequestHandler
Handler.directory = './other-directory/'

with socketserver.TCPServer(("", PORT), Handler) as httpd:
    print(Handler.directory)
    print("serving at port", PORT)
    httpd.serve_forever()
# Out:
# ./OOP/other-directory/
# serving at port 8081
# 127.0.0.1 - - [09/Sep/2019 10:17:19] "GET / HTTP/1.1" 304 -
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-fd430fa11cea> in <module>
#       9     print(Handler.directory)
#      10     print("serving at port", PORT)
# ---> 11     httpd.serve_forever()
#
# C:\ProgramData\Anaconda3\lib\socketserver.py in serve_forever(self, poll_interval)
#     230
#     231                 while not self.__shutdown_request:
# --> 232                     ready = selector.select(poll_interval)
#     233                     # bpo-35017: shutdown() called during select(), exit immediately.
#     234                     if self.__shutdown_request:
#
# C:\ProgramData\Anaconda3\lib\selectors.py in select(self, timeout)
#     321         ready = []
#     322         try:
# --> 323             r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     324         except InterruptedError:
#     325             return ready
#
# C:\ProgramData\Anaconda3\lib\selectors.py in _select(self, r, w, _, timeout)
#     312     if sys.platform == 'win32':
#     313         def _select(self, r, w, _, timeout=None):
# --> 314             r, w, x = select.select(r, w, w, timeout)
#     315             return r, w + x, []
#     316     else:
#
# KeyboardInterrupt:

# %%
from BaseHTTPServer import BaseHTTPRequestHandler, HTTPServer
from urlparse import parse_qs
import cgi

class GP(BaseHTTPRequestHandler):
    def _set_headers(self):
        self.send_response(200)
        self.send_header('Content-type', 'text/html')
        self.end_headers()
    def do_HEAD(self):
        self._set_headers()
    def do_GET(self):
        self._set_headers()
        print(self.path)
        print(parse_qs(self.path[2:]))
        self.wfile.write("<html><body><h1>Get Request Received!</h1></body></html>")
    def do_POST(self):
        self._set_headers()
        form = cgi.FieldStorage(
            fp=self.rfile,
            headers=self.headers,
            environ={'REQUEST_METHOD': 'POST'}
        )
        print(form.getvalue("foo"))
        print(form.getvalue("bin"))
        self.wfile.write("<html><body><h1>POST Request Received!</h1></body></html>")

def run(server_class=HTTPServer, handler_class=GP, port=8088):
    server_address = ('', port)
    httpd = server_class(server_address, handler_class)
    print('Server running at localhost:8088...')
    httpd.serve_forever()

run()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-841e210b378e> in <module>
# ----> 1 from BaseHTTPServer import BaseHTTPRequestHandler, HTTPServer
#       2 from urlparse import parse_qs
#       3 import cgi
#       4
#       5 class GP(BaseHTTPRequestHandler):
#
# ModuleNotFoundError: No module named 'BaseHTTPServer'
